# %% [markdown]
# ## Enunciado
#
# > Considere la información del proyecto cuya información aparece en la tabla adjunta:
# > 1. ¿Cuál es la probabilidad de terminar el proyecto entre 17 y 19 semanas?
# > 2. Como la probabilidad antes calculada le parece baja, reduzca, con mínimo coste la duración media del proyecto a 18 semanas. ¿Cuál será ahora la probabilidad de terminar en 18 semanas? ¿Por qué?
# > 3. ¿Se encuentran nivelados los recursos consumidos por este proyecto antes de reducir su duración a 18 semanas? De no ser así proceda a su nivelación (realice únicamente dos iteraciones con el algoritmo).
# > 4. Si su empresa sólo puede destinar a 6 personas a este proyecto, ¿se encuentran los recursos de mano de obra correctamente asignados tras la nivelación? Reprográmelo si fuera necesario de modo que se cumpla esta restricción.

# %%
# Alargamos el ancho de las celdas al 100%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import pandas as pd
import numpy as np

datos_enunciado = pd.DataFrame([
#  actividad, precedentes, duracion, varianza,  cur,  recursos, duracion_tope
     ('A',       '---  ',      2,        1,     -100,     2,         1        ),
     ('B',       '---  ',      4,        1,       30,     2,         2        ),  
     ('C',       'B    ',      1,        1,   np.inf,     2,         1        ),
     ('D',       'A    ',      3,        1,       50,     2,         1        ),
     ('E',       'B,D  ',      7,        1,       20,     2,         4        ), 
     ('F',       'C,D  ',      4,        1,       10,     2,         2        ),
     ('G',       '---  ',      1,        2,      100,     4,         1        ),
     ('H',       'G    ',     11,        2,       10,     2,         8        ),
     ('I',       'E,F,H',      2,        1,       50,     2,         1        ),
     ('J',       'E,F,H',      8,        1,        5,     2,         7        ),
] ,columns=['actividad', 'precedentes', 'duracion', 'varianza', 'cur', 'recursos', 'duracion_tope']).set_index('actividad')

datos_enunciado
# Out:
# <style>.container { width:100% !important; }</style>
#           precedentes  duracion  varianza         cur  recursos  duracion_tope
# actividad
# A               ---           2         1 -100.000000         2              1
# B               ---           4         1   30.000000         2              2
# C               B             1         1         inf         2              1
# D               A             3         1   50.000000         2              1
# E               B,D           7         1   20.000000         2              4
# F               C,D           4         1   10.000000         2              2
# G               ---           1         2  100.000000         4              1
# H               G            11         2   10.000000         2              8
# I               E,F,H         2         1   50.000000         2              1
# J               E,F,H         8         1    5.000000         2              7

# %% [markdown]
# ## Solución
# ### Apartado 1
#
# > ¿Cuál es la probabilidad de terminar el proyecto entre 17 y 19 semanas?

# %% [markdown]
# #### Duración media del proyecto

# %% [markdown]
# En pmule (project management at ULE) está el código que utilizamos para calcular los valores del PERT.

# %%
from pmule import GrafoProyecto

# %% [markdown]
# La clase PertGraph permite visualizar el grafo PERT, el diagrama de Gantt así como realizar el cálculo de tiempos tempranos, tardíos y de las holguras totales.

# %%
aristas = pd.DataFrame([
# actividad, nodo_inicial, nodo_final
  (  'A', 1, 2 ),
  (  'B', 1, 3 ),
  (  'C', 3, 6 ),
  (  'D', 2, 5 ),
  (  'E', 5, 7 ),
  (  'F', 6, 7 ),
  (  'G', 1, 4 ),
  (  'H', 4, 7 ),
  (  'I', 7, 9 ),
  (  'J', 7, 8 ),
  ( 'f1', 3, 5 ),
  ( 'f2', 8, 9 ),   

] ,columns=['actividad', 'nodo_inicial', 'nodo_final']).set_index('actividad')

datos_proyecto = pd.concat([datos_enunciado, aristas], axis=1, sort=False).set_index(aristas.index).fillna(0)
datos_proyecto
# Out:
#           precedentes  duracion  varianza         cur  recursos  \
# actividad
# A               ---         2.0       1.0 -100.000000       2.0
# B               ---         4.0       1.0   30.000000       2.0
# C               B           1.0       1.0         inf       2.0
# D               A           3.0       1.0   50.000000       2.0
# E               B,D         7.0       1.0   20.000000       2.0
# F               C,D         4.0       1.0   10.000000       2.0
# G               ---         1.0       2.0  100.000000       4.0
# H               G          11.0       2.0   10.000000       2.0
# I               E,F,H       2.0       1.0   50.000000       2.0
# J               E,F,H       8.0       1.0    5.000000       2.0
# f1                  0       0.0       0.0    0.000000       0.0
# f2                  0       0.0       0.0    0.000000       0.0
#
#            duracion_tope  nodo_inicial  nodo_final
# actividad
# A                    1.0             1           2
# B                    2.0             1           3
# C                    1.0             3           6
# D                    1.0             2           5
# E                    4.0             5           7
# F                    2.0             6           7
# G                    1.0             1           4
# H                    8.0             4           7
# I                    1.0             7           9
# J                    7.0             7           8
# f1                   0.0             3           5
# f2                   0.0             8           9

# %%
proyecto = GrafoProyecto(datos_proyecto)

# %% [markdown]
# ##### Grafo PERT con numeración de nodos

# %%
proyecto.pert(filename='pert_nodos.png',
              duraciones=None,
              orientation='portrait', ranksep=0.5, nodesep=0.7)

# %% [markdown]
# ##### Matriz de Zaderenko

# %%
zaderenko = proyecto.zaderenko(datos_proyecto['duracion'])
zaderenko
# Out:
#          1  2  3  4  5  6   7   8   9 temprano
# 1           2  4  1                          0
# 2                    3                       2
# 3                    0  1                    4
# 4                          11                1
# 5                           7                5
# 6                           4                5
# 7                               8   2       12
# 8                                   0       20
# 9                                           20
# tardios  0  2  5  1  5  8  12  20  20

# %%
resultados_pert = proyecto.calcula_pert(duraciones=datos_proyecto['duracion'])
resultados_pert['tiempos']
# Out:
#    tempranos  tardios
# 1        0.0      0.0
# 4        1.0      1.0
# 3        4.0      5.0
# 6        5.0      8.0
# 2        2.0      2.0
# 5        5.0      5.0
# 7       12.0     12.0
# 8       20.0     20.0
# 9       20.0     20.0

# %% [markdown]
# ##### Duración media del proyecto

# %% [markdown]
# La duración media del proyecto es:

# %%
duracion_media_proyecto = proyecto.duracion_proyecto(duraciones=datos_proyecto['duracion'])
duracion_media_proyecto
# Out:
# 20.0

# %% [markdown]
# #### Varianza de la duración del proyecto
# Para determinar la varianza de la duración del proyecto es necesario determinar la varianza de cada rama del camino crítico.

# %% [markdown]
# ##### Holguras

# %%
resultados_pert['H_total']
# Out:
# A     0.0
# B     1.0
# G     0.0
# D     0.0
# C     3.0
# f1    1.0
# H     0.0
# E     0.0
# F     3.0
# I     6.0
# J     0.0
# f2    0.0
# dtype: float64

# %% [markdown]
# ##### Camino crítico

# %%
camino_critico = proyecto.camino_critico(datos_proyecto['duracion'])
camino_critico
# Out:
# Index(['A', 'G', 'D', 'H', 'E', 'J', 'f2'], dtype='object')

# %% [markdown]
# ##### Grafo PERT con indicación del camino crítico

# %%
filename='pert_tiempos_apartado_1.png'
proyecto.pert(filename=filename,
              duraciones=datos_proyecto['duracion'],
              orientation='portrait', ranksep=0.5, nodesep=0.5)

# %% [markdown]
# ##### Varianza de cada rama

# %% [markdown]
# A la vista del grafo PERT el camino crítico se compone de 2 ramas.

# %%
rama_1 = ['A', 'D', 'E', 'J', 'f2']
rama_2 = ['G', 'H', 'J', 'f2']

# %% [markdown]
# ###### Varianza rama 1:

# %%
datos_proyecto.loc[rama_1, 'varianza']
# Out:
# actividad
# A     1.0
# D     1.0
# E     1.0
# J     1.0
# f2    0.0
# Name: varianza, dtype: float64

# %%
varianza_rama_1 = datos_proyecto.loc[rama_1, 'varianza'].sum()
varianza_rama_1
# Out:
# 4.0

# %% [markdown]
# ###### Varianza rama 2:

# %%
datos_proyecto.loc[rama_2, 'varianza']
# Out:
# actividad
# G     2.0
# H     2.0
# J     1.0
# f2    0.0
# Name: varianza, dtype: float64

# %%
varianza_rama_2 = datos_proyecto.loc[rama_2, 'varianza'].sum()
varianza_rama_2
# Out:
# 5.0

# %% [markdown]
# ##### Máximo de las varianzas de las ramas

# %%
varianza_proyecto = max([varianza_rama_1,
                         varianza_rama_2,
                        ])
varianza_proyecto
# Out:
# 5.0

# %%
desviacion_proyecto = varianza_proyecto ** 0.5
desviacion_proyecto
# Out:
# 2.23606797749979

# %% [markdown]
# #### Probabilidad de terminar entre 197 y 19 periodos

# %%
import scipy
from scipy.stats import norm

probabilidad_de_terminar_antes_de_19 = norm.cdf(19, loc=duracion_media_proyecto, scale=desviacion_proyecto)
probabilidad_de_terminar_antes_de_17 = norm.cdf(17, loc=duracion_media_proyecto, scale=desviacion_proyecto)

probabilidad_de_terminar_entre_17_y_19 = probabilidad_de_terminar_antes_de_19 - probabilidad_de_terminar_antes_de_17
probabilidad_de_terminar_entre_17_y_19 * 100
# Out:
# 23.75041755697886

# %% [markdown]
# ### Apartado 2
# > Como la probabilidad antes calculada le parece baja, reduzca, con mínimo coste la duración media del proyecto a 18 semanas.
# ¿Cuál será ahora la probabilidad de terminar en 18 semanas? ¿Y la probabilidad de terminar entre 19 y 17 semanas?

# %% [markdown]
# #### Reducción a 18 periodos

# %% [markdown]
# ##### Situación inicial de partida

# %%
filename='pert_apartado_2_situacion_inicial.png'
proyecto.pert(filename=filename,
              duraciones=datos_proyecto['duracion'],
              orientation='portrait', ranksep=0.5, nodesep=0.5)

# %% [markdown]
# Para analizar el efecto de la reducción de la duración usaremos una nueva matriz para almacenar los datos de las duraciones:

# %%
datos_proyecto_reduccion = datos_proyecto.copy()

# %% [markdown]
# ##### Primera reducción de la duración del proyecto en un periodo

# %% [markdown]
# Analizamos los costes unitarios de reducción y la capacidad de reducción de las actividades en cada rama del camino crítico.

# %% [markdown]
# ###### Análisis rama 1

# %%
datos_proyecto_reduccion.loc[rama_1, ['cur', 'duracion', 'duracion_tope']].sort_values(by='cur')
# Out:
#              cur  duracion  duracion_tope
# actividad
# A         -100.0       2.0            1.0
# f2           0.0       0.0            0.0
# J            5.0       8.0            7.0
# E           20.0       7.0            4.0
# D           50.0       3.0            1.0

# %% [markdown]
# En la rama 1 la actividad reducible más baratas es la A.

# %% [markdown]
# ###### Análisis rama 2

# %%
datos_proyecto_reduccion.loc[rama_2, ['cur', 'duracion', 'duracion_tope']].sort_values(by='cur')
# Out:
#              cur  duracion  duracion_tope
# actividad
# f2           0.0       0.0            0.0
# J            5.0       8.0            7.0
# H           10.0      11.0            8.0
# G          100.0       1.0            1.0

# %% [markdown]
# En la rama 2 la actividad reducible más barata es la J. Además es común a las dos ramas.

# %% [markdown]
# ###### Reducción de actividades en la primera iteración.

# %% [markdown]
# Se propone reducir un periodo la actividades J por ser común a las dos ramas. El coste asociado a esta reducción es:

# %%
datos_proyecto_reduccion.loc[['J'], 'cur'].sum()
# Out:
# 5.0

# %%
datos_proyecto_reduccion.loc[['J'], 'duracion'] -=1

# %%
filename='pert_apartado_2_primera_reduccion.png'
proyecto.pert(filename=filename,
              duraciones=datos_proyecto_reduccion['duracion'],
              orientation='portrait', ranksep=0.5, nodesep=0.5)

# %% [markdown]
# ##### Segunda reducción de la duración del proyecto en un periodo

# %% [markdown]
# ###### Análisis rama 1

# %%
datos_proyecto_reduccion.loc[rama_1, ['cur', 'duracion', 'duracion_tope']].sort_values(by='cur')
# Out:
#              cur  duracion  duracion_tope
# actividad
# A         -100.0       2.0            1.0
# f2           0.0       0.0            0.0
# J            5.0       7.0            7.0
# E           20.0       7.0            4.0
# D           50.0       3.0            1.0

# %% [markdown]
# En la rama 1 la actividad reducible más baratas es la A.

# %% [markdown]
# ###### Análisis rama 2

# %%
datos_proyecto_reduccion.loc[rama_2, ['cur', 'duracion', 'duracion_tope']].sort_values(by='cur')
# Out:
#              cur  duracion  duracion_tope
# actividad
# f2           0.0       0.0            0.0
# J            5.0       7.0            7.0
# H           10.0      11.0            8.0
# G          100.0       1.0            1.0

# %% [markdown]
# En la rama 2 la actividad reducible más barata es la H.

# %% [markdown]
# ###### Reducción de actividades en la segunda iteración.

# %% [markdown]
# Se propone reducir un periodo las actividades A y H. El coste asociado a tal reducción es:

# %%
datos_proyecto_reduccion.loc[['A', 'H'], 'cur'].sum()
# Out:
# -90.0

# %%
datos_proyecto_reduccion.loc[['A','H'], 'duracion'] -=1

# %%
filename='pert_apartado_2_segunda_reduccion.png'
proyecto.pert(filename=filename,
              duraciones=datos_proyecto_reduccion['duracion'],
              orientation='portrait', ranksep=0.5, nodesep=0.5)

# %% [markdown]
# #### Probabilidad de terminar antes de 18 periodos
# Al ser 18 el valor de la media de la duración, la probabilidad pedida es del 50%.

# %% [markdown]
# #### Probabilidad de terminar entre 19 y 17 semanas

# %% [markdown]
# ##### Duración media del proyecto

# %% [markdown]
# Nótese como al haber reducido la duración del proyecto la duración media a utilizar en el cálculo de la probabilidad es la nueva duración recortada de 18 periodos.

# %%
duracion_media_proyecto = proyecto.duracion_proyecto(duraciones=datos_proyecto_reduccion['duracion'])
duracion_media_proyecto
# Out:
# 18.0

# %% [markdown]
# ##### Varianza de la duración del proyecto

# %% [markdown]
# Al proyecto le ha surgido una nueva rama, que llamaremos rama 3. Debemos calcular la varianza de esta nueva rama y actualizar el valor de la varianza del proyecto si fuera menor que la de esta rama.

# %%
rama_3 = ['B', 'f1', 'E', 'J', 'f2']

# %%
datos_proyecto.loc[rama_3, 'varianza']
# Out:
# actividad
# B     1.0
# f1    0.0
# E     1.0
# J     1.0
# f2    0.0
# Name: varianza, dtype: float64

# %%
varianza_rama_3 = datos_proyecto.loc[rama_3, 'varianza'].sum()
varianza_rama_3
# Out:
# 3.0

# %%
varianza_proyecto = max([varianza_rama_1, varianza_rama_2, varianza_rama_3])
varianza_proyecto
# Out:
# 5.0

# %% [markdown]
# En este caso la varianza de la nueva rama es inferior a la ya calculada para el proyecto.

# %% [markdown]
# ##### Cálculo de la probabilidad

# %%
import scipy
from scipy.stats import norm

probabilidad_de_terminar_antes_de_19 = norm.cdf(19, loc=duracion_media_proyecto, scale=desviacion_proyecto)
probabilidad_de_terminar_antes_de_17 = norm.cdf(17, loc=duracion_media_proyecto, scale=desviacion_proyecto)

probabilidad_de_terminar_entre_17_y_19 = probabilidad_de_terminar_antes_de_19 - probabilidad_de_terminar_antes_de_17
probabilidad_de_terminar_entre_17_y_19 * 100
# Out:
# 34.527915398142305

# %% [markdown]
# ### Apartado 3
# > ¿Se encuentran nivelados los recursos consumidos por este proyecto antes de reducir su duración a 18 semanas? De no ser así proceda a su nivelación (realice únicamente dos iteraciones con el algoritmo).

# %% [markdown]
# #### Análisis de la situación inicial

# %% [markdown]
# Para responder este apartado es necesario representar la demanda de recursos a lo largo del tiempo.

# %%
gantt_recursos = proyecto.gantt(duraciones  = datos_proyecto['duracion'],
                                representar = datos_proyecto['recursos'],
                                total='fila',
                                holguras = True
                               )
gantt_recursos
# Out:
# <style  type="text/css" >
#     #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#           border: 1px solid;
#     }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771 td {
#           font-size: 11px;
#           border-color: #c0c0c0;
#           border: 1px solid;
#     }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771  {
#           border: 3px solid;
#     }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col0 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col1 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col2 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col3 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col4 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col5 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col6 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col7 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col8 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col9 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col10 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col11 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col12 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col13 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col14 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col15 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col16 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col17 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col18 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col19 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row0_col20 {
#             background-color:  sandybrown;
#             background:  #f7f7f9;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col0 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col1 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col2 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col3 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col4 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col5 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col6 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col7 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col8 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col9 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col10 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col11 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col12 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col13 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col14 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col15 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col16 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col17 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col18 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col19 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row1_col20 {
#             background-color:  sandybrown;
#             background:  #f7f7f9;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col0 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col1 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col2 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col3 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col4 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col5 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col6 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col7 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col8 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col9 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col10 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col11 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c0754343771row2_col12 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8a4a3634_ed7f_11e8_b3ca_3c075434377

# %%
(gantt_recursos.data.loc['Total']
   .drop('H_total')
   .plot(kind='bar'));

# %% [markdown]
# La demanda de recursos actual no se encuentra nivelada. Se procede a aplicar el algoritmo de nivelación.

# %% [markdown]
# #### Nivelación de los recursos

# %% [markdown]
# La suma de la serie de cuadrados de los recursos para la situación inicial es:

# %%
recursos_al_cuadrado = (gantt_recursos
                        .data
                        .loc['Total',:]
                        .drop('H_total')
                        ** 2)
recursos_al_cuadrado
# Out:
# 1     64
# 2     36
# 3     36
# 4     36
# 5     36
# 6     36
# 7     36
# 8     36
# 9     36
# 10    16
# 11    16
# 12    16
# 13    16
# 14    16
# 15     4
# 16     4
# 17     4
# 18     4
# 19     4
# 20     4
# Name: Total, dtype: object

# %%
recursos_al_cuadrado.sum()
# Out:
# 456.0

# %% [markdown]
# ##### Primera actuación

# %% [markdown]
# Se comienza buscando la actividad no crítica con su final más temprano más próximo al final del proyecto.

# %%
(proyecto.calendario(duraciones=datos_proyecto['duracion'])
 .loc[:, ['fin_mas_temprano', 'H_total']]
 .sort_values(by='fin_mas_temprano', ascending=False)
 .query('H_total > 0')
)
# Out:
#            fin_mas_temprano  H_total
# actividad
# I                      14.0      6.0
# F                       9.0      3.0
# C                       5.0      3.0
# B                       4.0      1.0
# f1                      4.0      1.0

# %% [markdown]
# Esta primera actividad en la que actuar es al I. Puede apreciarse también directamente en el diagrama de Gantt anterior. Se procede, por tanto, a desplazar un periodo la actividad I.

# %%
desplazamiento = proyecto.desplazar(duraciones=datos_proyecto['duracion'],
                                    actividades={'I': 1 })

nuevo_gantt_recursos = desplazamiento['proyecto'].gantt(duraciones=desplazamiento['duraciones'],
                                                        representar=datos_proyecto['recursos'],
                                                        total='fila',
                                                        holguras=True)
nuevo_gantt_recursos
# Out:
# <style  type="text/css" >
#     #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#           border: 1px solid;
#     }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771 td {
#           font-size: 11px;
#           border-color: #c0c0c0;
#           border: 1px solid;
#     }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771  {
#           border: 3px solid;
#     }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col0 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col1 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col2 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col3 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col4 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col5 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col6 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col7 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col8 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col9 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col10 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col11 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col12 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col13 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col14 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col15 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col16 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col17 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col18 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col19 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row0_col20 {
#             background-color:  sandybrown;
#             background:  #f7f7f9;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col0 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col1 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col2 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col3 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col4 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col5 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col6 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col7 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col8 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col9 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col10 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col11 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col12 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col13 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col14 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col15 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col16 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col17 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col18 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col19 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row1_col20 {
#             background-color:  sandybrown;
#             background:  #f7f7f9;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col0 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col1 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col2 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col3 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col4 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col5 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col6 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col7 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col8 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col9 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col10 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col11 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c0754343771row2_col12 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8acfda0a_ed7f_11e8_b6cd_3c075434377

# %% [markdown]
# La actividad *slide_I* representa el desplazamiento de las actividad I.

# %%
(nuevo_gantt_recursos.data.loc['Total']
   .drop('H_total')
   .plot(kind='bar'));

# %% [markdown]
# La suma de los cuadrados de los recursos es:

# %%
recursos_al_cuadrado_primera_actuacion = (nuevo_gantt_recursos
                                          .data
                                          .loc['Total',:]
                                          .drop('H_total')
                                          ** 2)
recursos_al_cuadrado_primera_actuacion.sum()
# Out:
# 456.0

# %% [markdown]
# Esta primera actuación no conlleva ninguna mejora en la nivelación.

# %% [markdown]
# ##### Segunda actuación

# %% [markdown]
# Se prosigue desplazando la actividad I otro periodo más al disponer de holgura para una actuación adicional.

# %%
desplazamiento = proyecto.desplazar(duraciones=datos_proyecto['duracion'],
                                    actividades={'I': 2 })

nuevo_gantt_recursos = desplazamiento['proyecto'].gantt(duraciones=desplazamiento['duraciones'],
                                                        representar=datos_proyecto['recursos'],
                                                        total='fila',
                                                        holguras=True)
nuevo_gantt_recursos
# Out:
# <style  type="text/css" >
#     #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#           border: 1px solid;
#     }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771 td {
#           font-size: 11px;
#           border-color: #c0c0c0;
#           border: 1px solid;
#     }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771  {
#           border: 3px solid;
#     }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col0 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col1 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col2 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col3 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col4 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col5 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col6 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col7 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col8 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col9 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col10 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col11 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col12 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col13 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col14 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col15 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col16 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col17 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col18 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col19 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row0_col20 {
#             background-color:  sandybrown;
#             background:  #f7f7f9;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col0 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col1 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col2 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col3 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col4 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col5 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col6 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col7 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col8 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col9 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col10 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col11 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col12 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col13 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col14 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col15 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col16 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col17 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col18 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col19 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row1_col20 {
#             background-color:  sandybrown;
#             background:  #f7f7f9;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col0 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col1 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col2 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col3 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col4 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col5 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col6 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col7 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col8 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col9 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col10 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col11 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c0754343771row2_col12 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8b484ea4_ed7f_11e8_b6c4_3c075434377

# %%
(nuevo_gantt_recursos.data.loc['Total']
   .drop('H_total')
   .plot(kind='bar'));

# %%
recursos_al_cuadrado_segunda_actuacion = (nuevo_gantt_recursos
                                          .data
                                          .loc['Total',:]
                                          .drop('H_total')
                                          ** 2)
recursos_al_cuadrado_segunda_actuacion.sum()
# Out:
# 456.0

# %% [markdown]
# Esta segunda actuación tampoco conlleva ninguna mejora en la nivelación. Sin embargo en el enunciado nos indican que sólo indiquemos las dos primeras actuaciones y por tanto no se continua nivelando.

# %% [markdown]
# ### Apartado 4
# > Si su empresa sólo puede destinar a 6 personas a este proyecto, ¿se encuentran los recursos de mano de obra correctamente asignados tras la nivelación? Reprogramelo si fuera necesario de modo que se cumpla esta restricción.

# %% [markdown]
# El proyecto requiere más de 6 personas en el primer periodo aplicar dos iteraciones del algoritmo de nivelación. Es necesario aplicar el algorimo de asignación. El primer periodo conflictivo es el 1.

# %% [markdown]
# ##### Asignación primer periodo

# %% [markdown]
# En el primer periodo la actividad B debe ser retrasada un periodo.

# %%
desplazamiento = proyecto.desplazar(duraciones=datos_proyecto['duracion'],
                                    actividades={'I': 2,
                                                 'B': 1})

nuevo_gantt_recursos = desplazamiento['proyecto'].gantt(duraciones=desplazamiento['duraciones'],
                                                        representar=datos_proyecto['recursos'],
                                                        total='fila',
                                                        holguras=True)
nuevo_gantt_recursos
# Out:
# <style  type="text/css" >
#     #T_8bccdda4_ed7f_11e8_8640_3c0754343771 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#           border: 1px solid;
#     }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771 td {
#           font-size: 11px;
#           border-color: #c0c0c0;
#           border: 1px solid;
#     }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771  {
#           border: 3px solid;
#     }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col0 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col1 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col2 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col3 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col4 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col5 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col6 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col7 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col8 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col9 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col10 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col11 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col12 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col13 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col14 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col15 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col16 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col17 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col18 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col19 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row0_col20 {
#             background-color:  sandybrown;
#             background:  #f7f7f9;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col0 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col1 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col2 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col3 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col4 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col5 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col6 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col7 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col8 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col9 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col10 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col11 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col12 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col13 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col14 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col15 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col16 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col17 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col18 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col19 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row1_col20 {
#             background-color:  sandybrown;
#             background:  #f7f7f9;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col0 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col1 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col2 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col3 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col4 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col5 {
#             background-color:  sandybrown;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col6 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col7 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col8 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col9 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col10 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col11 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c0754343771row2_col12 {
#             background-color:  white;
#             : ;
#             : ;
#         }    #T_8bccdda4_ed7f_11e8_8640_3c075434377

# %% [markdown]
# Tras esta actuación el proyecto ya es compatible con la restricción impuesta en los recursos.
