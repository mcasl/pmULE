# %% [markdown]
# ## Enunciado
#
# > Supongamos un proyecto para pintar la fachada de un edificio de planta cuadrada. Cada fachada se estima que tarde dos días en pintarse y conlleve un gasto de 2000 euros. Las fachadas se pintan consecutivamente. Hoy es el final del día 6 y el trabajo se encuentra de la siguiente manera:
# >    - Fachada 1: Acabado en el día 2, 2000 euros.
# >    - Fachada 2: Acabado en el día 5, 2400 euros.
# >    - Fachada 3: 50% acabado, 1200 euros.
# >    - Fachada 4: sin empezar.
# >
# > El coste final estimado por el contratista, LRE, es de 8200 euros.
# > Se pide realizar un analisis del valor ganado del proyecto a fecha actual (fin del día 6). Se admite un error de precisión de 0.02.
# > De las fórmulas estudiadas para el coste estimado final por el promotor utilice: EAC=BAC/CPI.

# %%
# %load_ext autoreload

from google.colab import drive
drive.mount('/content/gdrive/')
pmule_path = r'/content/gdrive/MyDrive/COMPARTIDOS/COMPARTIDO_AREA/DOCENCIA/Direccion_de_Proyectos/pmule/compartido_publico_alumnos/'

import sys
sys.path.insert(1, pmule_path + "src")
# !source {pmule_path}venv/bin/activate
# !apt install libgraphviz-dev
# !python -m pip install pygraphviz "pandas[excel]==2.2.2"
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgraphviz-dev is already the newest version (2.42.2-6ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Requirement already satisfied: pygraphviz in /usr/local/lib/python3.10/dist-packages (1.14)
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.10/dist-packages (from pandas[excel]==2.2.2) (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2->pandas[excel]==2.2.2) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2->pandas[excel]==2.2.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2->pandas[excel]==2.2.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2->pandas[excel]==2.2.2) (2024.2)
# Requirement already satisfied: odfpy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pandas[excel]==2.2.2) (1.4.1)
# Requirement already satisfied: openpyxl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from pandas[excel]==2.2.2) (3.1.5)
# Requirement already satisfied: python-calamine>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from pandas[excel]==2.2.2) (0.3.1)
# Requirement already satisfied: pyxlsb>=1.0.10 in /usr/local/lib/python3.10/dist-packages (from pandas[excel]==2.2.2) (1.0.10)
# Requirement already satisfied: xlrd>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from pandas[excel]==2.2.2) (2.0.1)
# Requirement already satisfied: xlsxwriter>=3.0.5 in /usr/local/lib/python3.10/dist-packages (from pandas[excel]==2.2.2) (3.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from odfpy>=1.4.1->pandas[excel]==2.2.2) (0.7.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl>=3.1.0->pandas[excel]==2.2.2) (2.0.0)
# Requirement already satisfied: packaging~=24.1 in /usr/local/lib/python3.10/dist-packages (from python-calamine>=0.1.7->pandas[excel]==2.2.2) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.2->pandas[excel]==2.2.2) (1.16.0)

# %%
# Alargamos el ancho de las celdas al 100%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

import pandas as pd
pd.set_option('future.no_silent_downcasting', True)

import numpy as np

datos_enunciado = pd.DataFrame([
#     actividad,   precedentes,  duracion,  coste_planificado,     coste_real,  duracion_real,  realizado
     ('Fachada_1', '---      ',       2,            2000,              2000,          2,       100,   ),
     ('Fachada_2', 'Fachada_1',       2,            2000,              2400,          3,       100,   ),
     ('Fachada_3', 'Fachada_2',       2,            2000,              1200,          1,        50,   ),
     ('Fachada_4', 'Fachada_3',       2,            2000,                 0,          0,           0,   ),
] ,columns=['actividad', 'precedentes', 'duracion',  'coste_planificado', 'coste_real', 'duracion_real',
            'realizado']).set_index('actividad')
datos_enunciado
# Out:
# <style>.container { width:80% !important; }</style>
#           precedentes  duracion  coste_planificado  coste_real  duracion_real  \
# actividad
# Fachada_1   ---               2               2000        2000              2
# Fachada_2   Fachada_1         2               2000        2400              3
# Fachada_3   Fachada_2         2               2000        1200              1
# Fachada_4   Fachada_3         2               2000           0              0
#
#            realizado
# actividad
# Fachada_1        100
# Fachada_2        100
# Fachada_3         50
# Fachada_4          0

# %% [markdown]
# ### Resolución

# %% [markdown]
# En pmule (project management at ULE) está el código que utilizamos para calcular los valores del PERT.

# %%
# %autoreload 2
from pmule import PredecessorTable, ProjectGraph, EarnedValue

# %%
datos_proyecto=datos_enunciado.copy()
prelaciones = PredecessorTable.from_dataframe_of_strings(datos_proyecto, activity='actividad', predecessor='precedentes')
prelaciones.display_immediate_linkage_matrix()
# Out:
# <style type="text/css">
# #T_9c497_row0_col0, #T_9c497_row0_col1, #T_9c497_row0_col2, #T_9c497_row0_col3, #T_9c497_row1_col1, #T_9c497_row1_col2, #T_9c497_row1_col3, #T_9c497_row2_col0, #T_9c497_row2_col2, #T_9c497_row2_col3, #T_9c497_row3_col0, #T_9c497_row3_col1, #T_9c497_row3_col3 {
#   background-color: white;
#   border: 1px solid black;
# }
# #T_9c497_row1_col0, #T_9c497_row2_col1, #T_9c497_row3_col2 {
#   background-color: cyan;
#   border: 1px solid black;
# }
# </style>
# <table id="T_9c497" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c497_level0_col0" class="col_heading level0 col0" >Fachada_1</th>
#       <th id="T_9c497_level0_col1" class="col_heading level0 col1" >Fachada_2</th>
#       <th id="T_9c497_level0_col2" class="col_heading level0 col2" >Fachada_3</th>
#       <th id="T_9c497_level0_col3" class="col_heading level0 col3" >Fachada_4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >activities</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c497_level0_row0" class="row_heading level0 row0" >Fachada_1</th>
#       <td id="T_9c497_row0_col0" class="data row0 col0" ></td>
#       <td id="T_9c497_row0_col1" class="data row0 col1" ></td>
#       <td id="T_9c497_row0_col2" class="data row0 col2" ></td>
#       <td id="T_9c497_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_9c497_level0_row1" class="row_heading level0 row1" >Fachada_2</th>
#       <td id="T_9c497_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_9c497_row1_col1" class="data row1 col1" ></td>
#       <td id="T_9c497_row1_col2" class="data row1 col2" ></td>
#       <td id="T_9c497_row1_col3" class="data row1 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_9c497_level0_row2" class="row_heading level0 row2" >Fachada_3</th>
#       <td id="T_9c497_row2_col0" class="data row2 col0" ></td>
#       <td id="T_9c497_row2_col1" class="data row2 col1" >True</td>
#       <td id="T_9c497_row2_col2" class="data row2 col2" ></td>
#       <td id="T_9c497_row2_col3" class="data row2 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_9c497_level0_row3" class="row_heading level0 row3" >Fachada_4</th>
#       <td id="T_9c497_row3_col0" class="data row3 col0" ></td>
#       <td id="T_9c497_row3_col1" class="data row3 col1" ></td>
#       <td id="T_9c497_row3_col2" class="data row3 col2" >True</td>
#       <td id="T_9c497_row3_col3" class="data row3 col3" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# La clase PertGraph permite visualizar el grafo PERT, el diagrama de Gantt así como realizar el cálculo de tiempos tempranos, tardíos y de las holguras totales.

# %%
proyecto = prelaciones.create_project()
proyecto.pert()

# %% [markdown]
# #### Gantt Valor Planificado

# %%
vg = EarnedValue(proyecto)

# %%
# %autoreload 2
from pmule import PredecessorTable, ProjectGraph, EarnedValue

# %%
datos_proyecto['duracion'] = datos_proyecto['duracion'].astype(float)
gantts = vg.calcula_gantts(data=datos_proyecto,
                           planned_durations_label = 'duracion',
                           actual_durations_label='duracion_real',
                           PV_label='coste_planificado',
                           AC_label='coste_real',
                           percentage_complete_label='realizado',
                          )

# %%
gantts['Gantt_PV']
# Out:
# <style type="text/css">
# #T_c7ace th {
#   font-size: 11px;
#   text-align: center;
#   font-weight: bold;
#   color: #6d6d6d;
#   background-color: #f7f7f9;
#   border: 1px solid;
# }
# #T_c7ace td {
#   font-size: 11px;
#   border-color: #c0c0c0;
#   border: 1px solid;
# }
# #T_c7ace  {
#   border: 3px solid;
# }
# #T_c7ace_row0_col0, #T_c7ace_row0_col1, #T_c7ace_row1_col2, #T_c7ace_row1_col3, #T_c7ace_row2_col4, #T_c7ace_row2_col5, #T_c7ace_row3_col6, #T_c7ace_row3_col7 {
#   background-color: sandybrown;
# }
# #T_c7ace_row0_col2, #T_c7ace_row0_col3, #T_c7ace_row0_col4, #T_c7ace_row0_col5, #T_c7ace_row0_col6, #T_c7ace_row0_col7, #T_c7ace_row1_col0, #T_c7ace_row1_col1, #T_c7ace_row1_col4, #T_c7ace_row1_col5, #T_c7ace_row1_col6, #T_c7ace_row1_col7, #T_c7ace_row2_col0, #T_c7ace_row2_col1, #T_c7ace_row2_col2, #T_c7ace_row2_col3, #T_c7ace_row2_col6, #T_c7ace_row2_col7, #T_c7ace_row3_col0, #T_c7ace_row3_col1, #T_c7ace_row3_col2, #T_c7ace_row3_col3, #T_c7ace_row3_col4, #T_c7ace_row3_col5 {
#   background-color: white;
# }
# #T_c7ace_row0_col8, #T_c7ace_row1_col8, #T_c7ace_row2_col8, #T_c7ace_row3_col8, #T_c7ace_row4_col0, #T_c7ace_row4_col1, #T_c7ace_row4_col2, #T_c7ace_row4_col3, #T_c7ace_row4_col4, #T_c7ace_row4_col5, #T_c7ace_row4_col6, #T_c7ace_row4_col7, #T_c7ace_row5_col0, #T_c7ace_row5_col1, #T_c7ace_row5_col2, #T_c7ace_row5_col3, #T_c7ace_row5_col4, #T_c7ace_row5_col5, #T_c7ace_row5_col6, #T_c7ace_row5_col7 {
#   background-color: sandybrown;
#   background: #f7f7f9;
# }
# #T_c7ace_row4_col8 {
#   background-color: sandybrown;
#   background: #f7f7f9;
#   background: #f7f7f9;
# }
# #T_c7ace_row5_col8 {
#   background-color: white;
#   background: #f7f7f9;
#   background: #f7f7f9;
# }
# </style>
# <table id="T_c7ace" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7ace_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_c7ace_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_c7ace_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_c7ace_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_c7ace_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_c7ace_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_c7ace_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_c7ace_level0_col7" class="col_heading level0 col7" >8</th>
#       <th id="T_c7ace_level0_col8" class="col_heading level0 col8" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7ace_level0_row0" class="row_heading level0 row0" >Fachada_1</th>
#       <td id="T_c7ace_row0_col0" class="data row0 col0" >1000.000000</td>
#       <td id="T_c7ace_row0_col1" class="data row0 col1" >1000.000000</td>
#       <td id="T_c7ace_row0_col2" class="data row0 col2" ></td>
#       <td id="T_c7ace_row0_col3" class="data row0 col3" ></td>
#       <td id="T_c7ace_row0_col4" class="data row0 col4" ></td>
#       <td id="T_c7ace_row0_col5" class="data row0 col5" ></td>
#       <td id="T_c7ace_row0_col6" class="data row0 col6" ></td>
#       <td id="T_c7ace_row0_col7" class="data row0 col7" ></td>
#       <td id="T_c7ace_row0_col8" class="data row0 col8" >2000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7ace_level0_row1" class="row_heading level0 row1" >Fachada_2</th>
#       <td id="T_c7ace_row1_col0" class="data row1 col0" ></td>
#       <td id="T_c7ace_row1_col1" class="data row1 col1" ></td>
#       <td id="T_c7ace_row1_col2" class="data row1 col2" >1000.000000</td>
#       <td id="T_c7ace_row1_col3" class="data row1 col3" >1000.000000</td>
#       <td id="T_c7ace_row1_col4" class="data row1 col4" ></td>
#       <td id="T_c7ace_row1_col5" class="data row1 col5" ></td>
#       <td id="T_c7ace_row1_col6" class="data row1 col6" ></td>
#       <td id="T_c7ace_row1_col7" class="data row1 col7" ></td>
#       <td id="T_c7ace_row1_col8" class="data row1 col8" >2000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7ace_level0_row2" class="row_heading level0 row2" >Fachada_3</th>
#       <td id="T_c7ace_row2_col0" class="data row2 col0" ></td>
#       <td id="T_c7ace_row2_col1" class="data row2 col1" ></td>
#       <td id="T_c7ace_row2_col2" class="data row2 col2" ></td>
#       <td id="T_c7ace_row2_col3" class="data row2 col3" ></td>
#       <td id="T_c7ace_row2_col4" class="data row2 col4" >1000.000000</td>
#       <td id="T_c7ace_row2_col5" class="data row2 col5" >1000.000000</td>
#       <td id="T_c7ace_row2_col6" class="data row2 col6" ></td>
#       <td id="T_c7ace_row2_col7" class="data row2 col7" ></td>
#       <td id="T_c7ace_row2_col8" class="data row2 col8" >2000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7ace_level0_row3" class="row_heading level0 row3" >Fachada_4</th>
#       <td id="T_c7ace_row3_col0" class="data row3 col0" ></td>
#       <td id="T_c7ace_row3_col1" class="data row3 col1" ></td>
#       <td id="T_c7ace_row3_col2" class="data row3 col2" ></td>
#       <td id="T_c7ace_row3_col3" class="data row3 col3" ></td>
#       <td id="T_c7ace_row3_col4" class="data row3 col4" ></td>
#       <td id="T_c7ace_row3_col5" class="data row3 col5" ></td>
#       <td id="T_c7ace_row3_col6" class="data row3 col6" >1000.000000</td>
#       <td id="T_c7ace_row3_col7" class="data row3 col7" >1000.000000</td>
#       <td id="T_c7ace_row3_col8" class="data row3 col8" >2000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7ace_level0_row4" class="row_heading level0 row4" >Total</th>
#       <td id="T_c7ace_row4_col0" class="data row4 col0" >1000.000000</td>
#       <td id="T_c7ace_row4_col1" class="data row4 col1" >1000.000000</td>
#       <td id="T_c7ace_row4_col2" class="data row4 col2" >1000.000000</td>
#       <td id="T_c7ace_row4_col3" class="data row4 col3" >1000.000000</td>
#       <td id="T_c7ace_row4_col4" class="data row4 col4" >1000.000000</td>
#       <td id="T_c7ace_row4_col5" class="data row4 col5" >1000.000000</td>
#       <td id="T_c7ace_row4_col6" class="data row4 col6" >1000.000000</td>
#       <td id="T_c7ace_row4_col7" class="data row4 col7" >1000.000000</td>
#       <td id="T_c7ace_row4_col8" class="data row4 col8" >8000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7ace_level0_row5" class="row_heading level0 row5" >Acumulado</th>
#       <td id="T_c7ace_row5_col0" class="data row5 col0" >1000.000000</td>
#       <td id="T_c7ace_row5_col1" class="data row5 col1" >2000.000000</td>
#       <td id="T_c7ace_row5_col2" class="data row5 col2" >3000.000000</td>
#       <td id="T_c7ace_row5_col3" class="data row5 col3" >4000.000000</td>
#       <td id="T_c7ace_row5_col4" class="data row5 col4" >5000.000000</td>
#       <td id="T_c7ace_row5_col5" class="data row5 col5" >6000.000000</td>
#       <td id="T_c7ace_row5_col6" class="data row5 col6" >7000.000000</td>
#       <td id="T_c7ace_row5_col7" class="data row5 col7" >8000.000000</td>
#       <td id="T_c7ace_row5_col8" class="data row5 col8" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Gantt Valor Ganado

# %%
gantts['Gantt_EV']
# Out:
# <style type="text/css">
# #T_b97b4 th {
#   font-size: 11px;
#   text-align: center;
#   font-weight: bold;
#   color: #6d6d6d;
#   background-color: #f7f7f9;
#   border: 1px solid;
# }
# #T_b97b4 td {
#   font-size: 11px;
#   border-color: #c0c0c0;
#   border: 1px solid;
# }
# #T_b97b4  {
#   border: 3px solid;
# }
# #T_b97b4_row0_col0, #T_b97b4_row0_col1, #T_b97b4_row1_col2, #T_b97b4_row1_col3, #T_b97b4_row1_col4, #T_b97b4_row2_col5 {
#   background-color: sandybrown;
# }
# #T_b97b4_row0_col2, #T_b97b4_row0_col3, #T_b97b4_row0_col4, #T_b97b4_row0_col5, #T_b97b4_row1_col0, #T_b97b4_row1_col1, #T_b97b4_row1_col5, #T_b97b4_row2_col0, #T_b97b4_row2_col1, #T_b97b4_row2_col2, #T_b97b4_row2_col3, #T_b97b4_row2_col4 {
#   background-color: white;
# }
# #T_b97b4_row0_col6, #T_b97b4_row1_col6, #T_b97b4_row2_col6, #T_b97b4_row3_col0, #T_b97b4_row3_col1, #T_b97b4_row3_col2, #T_b97b4_row3_col3, #T_b97b4_row3_col4, #T_b97b4_row3_col5, #T_b97b4_row4_col0, #T_b97b4_row4_col1, #T_b97b4_row4_col2, #T_b97b4_row4_col3, #T_b97b4_row4_col4, #T_b97b4_row4_col5 {
#   background-color: sandybrown;
#   background: #f7f7f9;
# }
# #T_b97b4_row3_col6 {
#   background-color: sandybrown;
#   background: #f7f7f9;
#   background: #f7f7f9;
# }
# #T_b97b4_row4_col6 {
#   background-color: white;
#   background: #f7f7f9;
#   background: #f7f7f9;
# }
# </style>
# <table id="T_b97b4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b97b4_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_b97b4_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_b97b4_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_b97b4_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_b97b4_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_b97b4_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_b97b4_level0_col6" class="col_heading level0 col6" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b97b4_level0_row0" class="row_heading level0 row0" >Fachada_1</th>
#       <td id="T_b97b4_row0_col0" class="data row0 col0" >500.000000</td>
#       <td id="T_b97b4_row0_col1" class="data row0 col1" >500.000000</td>
#       <td id="T_b97b4_row0_col2" class="data row0 col2" ></td>
#       <td id="T_b97b4_row0_col3" class="data row0 col3" ></td>
#       <td id="T_b97b4_row0_col4" class="data row0 col4" ></td>
#       <td id="T_b97b4_row0_col5" class="data row0 col5" ></td>
#       <td id="T_b97b4_row0_col6" class="data row0 col6" >1000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b97b4_level0_row1" class="row_heading level0 row1" >Fachada_2</th>
#       <td id="T_b97b4_row1_col0" class="data row1 col0" ></td>
#       <td id="T_b97b4_row1_col1" class="data row1 col1" ></td>
#       <td id="T_b97b4_row1_col2" class="data row1 col2" >333.333333</td>
#       <td id="T_b97b4_row1_col3" class="data row1 col3" >333.333333</td>
#       <td id="T_b97b4_row1_col4" class="data row1 col4" >333.333333</td>
#       <td id="T_b97b4_row1_col5" class="data row1 col5" ></td>
#       <td id="T_b97b4_row1_col6" class="data row1 col6" >1000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b97b4_level0_row2" class="row_heading level0 row2" >Fachada_3</th>
#       <td id="T_b97b4_row2_col0" class="data row2 col0" ></td>
#       <td id="T_b97b4_row2_col1" class="data row2 col1" ></td>
#       <td id="T_b97b4_row2_col2" class="data row2 col2" ></td>
#       <td id="T_b97b4_row2_col3" class="data row2 col3" ></td>
#       <td id="T_b97b4_row2_col4" class="data row2 col4" ></td>
#       <td id="T_b97b4_row2_col5" class="data row2 col5" >500.000000</td>
#       <td id="T_b97b4_row2_col6" class="data row2 col6" >500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b97b4_level0_row3" class="row_heading level0 row3" >Total</th>
#       <td id="T_b97b4_row3_col0" class="data row3 col0" >500.000000</td>
#       <td id="T_b97b4_row3_col1" class="data row3 col1" >500.000000</td>
#       <td id="T_b97b4_row3_col2" class="data row3 col2" >333.333333</td>
#       <td id="T_b97b4_row3_col3" class="data row3 col3" >333.333333</td>
#       <td id="T_b97b4_row3_col4" class="data row3 col4" >333.333333</td>
#       <td id="T_b97b4_row3_col5" class="data row3 col5" >500.000000</td>
#       <td id="T_b97b4_row3_col6" class="data row3 col6" >2500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b97b4_level0_row4" class="row_heading level0 row4" >Acumulado</th>
#       <td id="T_b97b4_row4_col0" class="data row4 col0" >500.000000</td>
#       <td id="T_b97b4_row4_col1" class="data row4 col1" >1000.000000</td>
#       <td id="T_b97b4_row4_col2" class="data row4 col2" >1333.333333</td>
#       <td id="T_b97b4_row4_col3" class="data row4 col3" >1666.666667</td>
#       <td id="T_b97b4_row4_col4" class="data row4 col4" >2000.000000</td>
#       <td id="T_b97b4_row4_col5" class="data row4 col5" >2500.000000</td>
#       <td id="T_b97b4_row4_col6" class="data row4 col6" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Gantt Coste Real

# %%
gantts['Gantt_AC']
# Out:
# <style type="text/css">
# #T_e3611 th {
#   font-size: 11px;
#   text-align: center;
#   font-weight: bold;
#   color: #6d6d6d;
#   background-color: #f7f7f9;
#   border: 1px solid;
# }
# #T_e3611 td {
#   font-size: 11px;
#   border-color: #c0c0c0;
#   border: 1px solid;
# }
# #T_e3611  {
#   border: 3px solid;
# }
# #T_e3611_row0_col0, #T_e3611_row0_col1, #T_e3611_row1_col2, #T_e3611_row1_col3, #T_e3611_row1_col4, #T_e3611_row2_col5 {
#   background-color: sandybrown;
# }
# #T_e3611_row0_col2, #T_e3611_row0_col3, #T_e3611_row0_col4, #T_e3611_row0_col5, #T_e3611_row1_col0, #T_e3611_row1_col1, #T_e3611_row1_col5, #T_e3611_row2_col0, #T_e3611_row2_col1, #T_e3611_row2_col2, #T_e3611_row2_col3, #T_e3611_row2_col4 {
#   background-color: white;
# }
# #T_e3611_row0_col6, #T_e3611_row1_col6, #T_e3611_row2_col6, #T_e3611_row3_col0, #T_e3611_row3_col1, #T_e3611_row3_col2, #T_e3611_row3_col3, #T_e3611_row3_col4, #T_e3611_row3_col5, #T_e3611_row4_col0, #T_e3611_row4_col1, #T_e3611_row4_col2, #T_e3611_row4_col3, #T_e3611_row4_col4, #T_e3611_row4_col5 {
#   background-color: sandybrown;
#   background: #f7f7f9;
# }
# #T_e3611_row3_col6 {
#   background-color: sandybrown;
#   background: #f7f7f9;
#   background: #f7f7f9;
# }
# #T_e3611_row4_col6 {
#   background-color: white;
#   background: #f7f7f9;
#   background: #f7f7f9;
# }
# </style>
# <table id="T_e3611" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3611_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_e3611_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_e3611_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_e3611_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_e3611_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_e3611_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_e3611_level0_col6" class="col_heading level0 col6" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3611_level0_row0" class="row_heading level0 row0" >Fachada_1</th>
#       <td id="T_e3611_row0_col0" class="data row0 col0" >1000.000000</td>
#       <td id="T_e3611_row0_col1" class="data row0 col1" >1000.000000</td>
#       <td id="T_e3611_row0_col2" class="data row0 col2" ></td>
#       <td id="T_e3611_row0_col3" class="data row0 col3" ></td>
#       <td id="T_e3611_row0_col4" class="data row0 col4" ></td>
#       <td id="T_e3611_row0_col5" class="data row0 col5" ></td>
#       <td id="T_e3611_row0_col6" class="data row0 col6" >2000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e3611_level0_row1" class="row_heading level0 row1" >Fachada_2</th>
#       <td id="T_e3611_row1_col0" class="data row1 col0" ></td>
#       <td id="T_e3611_row1_col1" class="data row1 col1" ></td>
#       <td id="T_e3611_row1_col2" class="data row1 col2" >800.000000</td>
#       <td id="T_e3611_row1_col3" class="data row1 col3" >800.000000</td>
#       <td id="T_e3611_row1_col4" class="data row1 col4" >800.000000</td>
#       <td id="T_e3611_row1_col5" class="data row1 col5" ></td>
#       <td id="T_e3611_row1_col6" class="data row1 col6" >2400.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e3611_level0_row2" class="row_heading level0 row2" >Fachada_3</th>
#       <td id="T_e3611_row2_col0" class="data row2 col0" ></td>
#       <td id="T_e3611_row2_col1" class="data row2 col1" ></td>
#       <td id="T_e3611_row2_col2" class="data row2 col2" ></td>
#       <td id="T_e3611_row2_col3" class="data row2 col3" ></td>
#       <td id="T_e3611_row2_col4" class="data row2 col4" ></td>
#       <td id="T_e3611_row2_col5" class="data row2 col5" >1200.000000</td>
#       <td id="T_e3611_row2_col6" class="data row2 col6" >1200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e3611_level0_row3" class="row_heading level0 row3" >Total</th>
#       <td id="T_e3611_row3_col0" class="data row3 col0" >1000.000000</td>
#       <td id="T_e3611_row3_col1" class="data row3 col1" >1000.000000</td>
#       <td id="T_e3611_row3_col2" class="data row3 col2" >800.000000</td>
#       <td id="T_e3611_row3_col3" class="data row3 col3" >800.000000</td>
#       <td id="T_e3611_row3_col4" class="data row3 col4" >800.000000</td>
#       <td id="T_e3611_row3_col5" class="data row3 col5" >1200.000000</td>
#       <td id="T_e3611_row3_col6" class="data row3 col6" >5600.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e3611_level0_row4" class="row_heading level0 row4" >Acumulado</th>
#       <td id="T_e3611_row4_col0" class="data row4 col0" >1000.000000</td>
#       <td id="T_e3611_row4_col1" class="data row4 col1" >2000.000000</td>
#       <td id="T_e3611_row4_col2" class="data row4 col2" >2800.000000</td>
#       <td id="T_e3611_row4_col3" class="data row4 col3" >3600.000000</td>
#       <td id="T_e3611_row4_col4" class="data row4 col4" >4400.000000</td>
#       <td id="T_e3611_row4_col5" class="data row4 col5" >5600.000000</td>
#       <td id="T_e3611_row4_col6" class="data row4 col6" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
acumulados = gantts['acumulados']
acumulados.plot();

# %%
acumulados.tail(1)
# Out:
#        PV      EV      AC
# 6  6000.0  2500.0  5600.0

# %% [markdown]
# #### Cálculo de parámetros diversos

# %%
EV = acumulados.tail(1)['EV']
EV
# Out:
# 6    2500.0
# Name: EV, dtype: object

# %%
AC = acumulados.tail(1)['AC']
AC
# Out:
# 6    5600.0
# Name: AC, dtype: object

# %%
PV = acumulados.tail(1)['PV']
PV
# Out:
# 6    6000.0
# Name: PV, dtype: object

# %%
CPI = EV/AC
CPI
# Out:
# 6    0.446429
# dtype: object

# %%
SPI = EV/PV
SPI
# Out:
# 6    0.416667
# dtype: object

# %%
BAC = datos_enunciado.loc[:, 'coste_planificado'].sum()
BAC
# Out:
# 8000

# %%
EAC = BAC / CPI
EAC
# Out:
# 6    17920.0
# dtype: object

# %%
CV = EV - AC
CV
# Out:
# 6   -3100.0
# dtype: object

# %%
CV_por_ciento = CV/EV *100
CV_por_ciento
# Out:
# 6   -124.0
# dtype: object

# %%
SV = EV - PV
SV
# Out:
# 6   -3500.0
# dtype: object

# %%
SV_por_ciento = SV/PV *100
SV_por_ciento
# Out:
# 6   -58.333333
# dtype: object

# %%
VAC = BAC - EAC
VAC
# Out:
# 6   -9920.0
# dtype: object

# %%
PC = EV / BAC
PC
# Out:
# 6    0.3125
# Name: EV, dtype: object

# %%
PS = AC / BAC
PS
# Out:
# 6    0.7
# Name: AC, dtype: object

# %%
PP = PV / BAC
PP
# Out:
# 6    0.75
# Name: PV, dtype: object

# %%
TCPI_BAC = (BAC - EV)/(BAC - AC)
TCPI_BAC
# Out:
# 6    2.291667
# dtype: object

# %%
TCPI_EAC = (BAC - EV)/(EAC - AC)
TCPI_EAC
# Out:
# 6    0.446429
# dtype: object

# %%
LRE = 8200
TCPI_LRE = (BAC - EV)/(LRE - AC)
TCPI_LRE
# Out:
# 6    2.115385
# dtype: object

# %% [markdown]
# La diferencia de rendimiento en costes indica que el LRE proporcionado no es verosimil.
